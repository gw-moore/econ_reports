# %%
import datetime
from dateutil.relativedelta import relativedelta
import pyfredapi as pf
from rich import print as rprint
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.api import acf, graphics, pacf
from statsmodels.tsa.ar_model import AutoReg, ar_select_order

# %%
housing_starts = pf.SeriesCollection()
housing_starts.add_series("HOUSTNSA")
# Out:
# Requesting series HOUSTNSA...

# %%
data = pdr.get_data_fred("HOUSTNSA", "1959-01-01", "2019-06-01")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 data = pdr.get_data_fred("HOUSTNSA", "1959-01-01", "2019-06-01")
#
# NameError: name 'pdr' is not defined

# %%
housing_starts.HOUSTNSA.plot()

# %%
housing = housing_starts.HOUSTNSA.df.HOUSTNSA.pct_change().dropna()

# %%
px.line(housing_starts_pct_chg)

# %%
mod = AutoReg(housing_starts.HOUSTNSA.df.HOUSTNSA, 3, old_names=False)
res = mod.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:               HOUSTNSA   No. Observations:                  765
# Model:                     AutoReg(3)   Log Likelihood               -3191.228
# Method:               Conditional MLE   S.D. of innovations             15.943
# Date:                Sat, 22 Oct 2022   AIC                           6392.457
# Time:                        23:37:31   BIC                           6415.636
# Sample:                             3   HQIC                          6401.382
#                                   765
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          15.9749      2.027      7.881      0.000      12.002      19.948
# HOUSTNSA.L1     1.0818      0.036     30.033      0.000       1.011       1.152
# HOUSTNSA.L2    -0.1179      0.053     -2.222      0.026      -0.222      -0.014
# ...

# %%
fig = res.plot_predict(720, 840)
# Out:
# /Users/gwmoore/Develop/econ_reports/.venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /Users/gwmoore/Develop/econ_reports/.venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /Users/gwmoore/Develop/econ_reports/.venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
mod = AutoReg(housing, 3, old_names=False)
res = mod.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:               HOUSTNSA   No. Observations:                  764
# Model:                     AutoReg(3)   Log Likelihood                 358.195
# Method:               Conditional MLE   S.D. of innovations              0.151
# Date:                Sat, 22 Oct 2022   AIC                           -706.390
# Time:                        23:37:56   BIC                           -683.217
# Sample:                             3   HQIC                          -697.467
#                                   764
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0112      0.006      2.031      0.042       0.000       0.022
# HOUSTNSA.L1     0.1820      0.036      5.118      0.000       0.112       0.252
# HOUSTNSA.L2     0.0072      0.036      0.198      0.843      -0.064       0.078
# ...
