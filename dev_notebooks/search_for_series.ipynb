# %% [markdown]
# ## Example of how to search for series with `pyfredapi`

# %%
import pyfredapi as pf
from rich.pretty import pprint

# %%
pprint(pf.search_series(
    search_text="CPI",
    return_format="json",
    **{"filter_variable": "seasonal_adjustment", "filter_value": "Seasonally Adjusted"}
))
# Out:
# {
# │   'realtime_start': '2022-10-29',
# │   'realtime_end': '2022-10-29',
# │   'filter_variable': 'seasonal_adjustment',
# │   'filter_value': 'Seasonally Adjusted',
# │   'order_by': 'search_rank',
# │   'sort_order': 'desc',
# │   'count': 253,
# │   'offset': 0,
# │   'limit': 1000,
# │   'seriess': [
# │   │   {
# │   │   │   'id': 'CPIAUCSL',
# │   │   │   'realtime_start': '2022-10-29',
# │   │   │   'realtime_end': '2022-10-29',
# │   │   │   'title': 'Consumer Price Index for All Urban Consumers: All Items in U.S. City Average',
# │   │   │   'observation_start': '1947-01-01',
# │   │   │   'observation_end': '2022-09-01',
# │   │   │   'frequency': 'Monthly',
# │   │   │   'frequency_short': 'M',
# │   │   │   'units': 'Index 1982-1984=100',
# │   │   │   'units_short': 'Index 1982-1984=100',
# │   │   │   'seasonal_adjustment': 'Seasonally Adjusted',
# │   │   │   'seasonal_adjustment_short': 'SA',
# │   │   │   'last_updated': '2022-10-13 07:37:02-05',
# ...

# %%
pprint(pf.search_series(
    "All-Transactions House Price Index",
    return_format="json",
    **{"filter_variable": "seasonal_adjustment", "filter_value": "Seasonally Adjusted"}
))
# Out:
# {
# │   'realtime_start': '2022-10-29',
# │   'realtime_end': '2022-10-29',
# │   'filter_variable': 'seasonal_adjustment',
# │   'filter_value': 'Seasonally Adjusted',
# │   'order_by': 'search_rank',
# │   'sort_order': 'desc',
# │   'count': 1,
# │   'offset': 0,
# │   'limit': 1000,
# │   'seriess': [
# │   │   {
# │   │   │   'id': 'ATNHPIUS16020Q',
# │   │   │   'realtime_start': '2022-10-29',
# │   │   │   'realtime_end': '2022-10-29',
# │   │   │   'title': 'All-Transactions House Price Index for Cape Girardeau, MO-IL (MSA)',
# │   │   │   'observation_start': '1987-04-01',
# │   │   │   'observation_end': '2022-04-01',
# │   │   │   'frequency': 'Quarterly',
# │   │   │   'frequency_short': 'Q',
# │   │   │   'units': 'Index 1995:Q1=100',
# │   │   │   'units_short': 'Index 1995 Q1=100',
# │   │   │   'seasonal_adjustment': 'Seasonally Adjusted',
# │   │   │   'seasonal_adjustment_short': 'SA',
# │   │   │   'last_updated': '2022-08-30 09:03:37-05',
# ...
